# %%
from classes.logger import log
from classes.cuda_setup import device
from classes.models import DQNImage, DQNStateSpace
from classes.gym_env import GymEnv
from classes.plotting import plot_durations
from classes.learner import Learner
from classes.simulator import Simulator

env = GymEnv('CartPole-v0')

constants = {
             "BATCH_SIZE" : 128,
             "GAMMA" : 0.999, #0.999,
             "EPS_START" : 0.9,
             "EPS_END" : 0.3,
             "EPS_DECAY" : 1000 #200
            }

constants = {
             "BATCH_SIZE" : 128,
             "GAMMA" : 0.999, #0.999,
             "EPS_START" : 0.9,
             "EPS_END" : 0.05,
             "EPS_DECAY" : 200 #200
            }
network = DQNImage(env.env)
#network = DQNStateSpace(env.env)

lnr = Learner(network, constants)


sim = Simulator(env, lnr, TARGET_UPDATE = 10)

# %%
log.setLevel("INFO")

# %%
sim.simulate(5)
# Out:
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# INFO:logger:Episode: 1
# INFO:logger:Episode: 2
# INFO:logger:Episode: 3
# INFO:logger:Episode: 4
# INFO:logger:Episode: 5

# %%
plot_durations(sim.episode_durations)

# %%
sim.simulate(50)
# Out:
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))
# INFO:logger:Episode: 6
# INFO:logger:Episode: 7
# INFO:logger:Episode: 8
# INFO:logger:Episode: 9
# INFO:logger:Episode: 10
# INFO:logger:Episode: 11
# INFO:logger:Episode: 12
# INFO:logger:Episode: 13
# INFO:logger:Episode: 14
# INFO:logger:Episode: 15
# INFO:logger:Episode: 16
# INFO:logger:Episode: 17
# INFO:logger:Episode: 18
# INFO:logger:Episode: 19
# INFO:logger:Episode: 20
# INFO:logger:Episode: 21
# INFO:logger:Episode: 22
# INFO:logger:Episode: 23
# INFO:logger:Episode: 24
# INFO:logger:Episode: 25
# INFO:logger:Episode: 26
# INFO:logger:Episode: 27
# INFO:logger:Episode: 28
# INFO:logger:Episode: 29
# INFO:logger:Episode: 30
# INFO:logger:Episode: 31
# INFO:logger:Episode: 32
# INFO:logger:Episode: 33
# INFO:logger:Episode: 34
# INFO:logger:Episode: 35
# INFO:logger:Episode: 36
# INFO:logger:Episode: 37
# INFO:logger:Episode: 38
# INFO:logger:Episode: 39
# INFO:logger:Episode: 40
# INFO:logger:Episode: 41
# INFO:logger:Episode: 42
# INFO:logger:Episode: 43
# INFO:logger:Episode: 44
# INFO:logger:Episode: 45
# INFO:logger:Episode: 46
# INFO:logger:Episode: 47
# INFO:logger:Episode: 48
# INFO:logger:Episode: 49
# INFO:logger:Episode: 50
# INFO:logger:Episode: 51
# INFO:logger:Episode: 52
# INFO:logger:Episode: 53
# INFO:logger:Episode: 54
# INFO:logger:Episode: 55

# %%
plot_durations(sim.episode_durations)

# %%
sim.simulate(100)
plot_durations(sim.episode_durations)
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# INFO:logger:Episode: 56
# INFO:logger:Episode: 57
# INFO:logger:Episode: 58
# INFO:logger:Episode: 59
# INFO:logger:Episode: 60
# INFO:logger:Episode: 61
# INFO:logger:Episode: 62
# INFO:logger:Episode: 63
# INFO:logger:Episode: 64
# INFO:logger:Episode: 65
# INFO:logger:Episode: 66
# INFO:logger:Episode: 67
# INFO:logger:Episode: 68
# INFO:logger:Episode: 69
# INFO:logger:Episode: 70
# INFO:logger:Episode: 71
# INFO:logger:Episode: 72
# INFO:logger:Episode: 73
# INFO:logger:Episode: 74
# INFO:logger:Episode: 75
# INFO:logger:Episode: 76
# INFO:logger:Episode: 77
# INFO:logger:Episode: 78
# INFO:logger:Episode: 79
# INFO:logger:Episode: 80
# INFO:logger:Episode: 81
# INFO:logger:Episode: 82
# INFO:logger:Episode: 83
# INFO:logger:Episode: 84
# INFO:logger:Episode: 85
# INFO:logger:Episode: 86
# INFO:logger:Episode: 87
# INFO:logger:Episode: 88
# INFO:logger:Episode: 89
# INFO:logger:Episode: 90
# INFO:logger:Episode: 91
# INFO:logger:Episode: 92
# INFO:logger:Episode: 93
# INFO:logger:Episode: 94
# INFO:logger:Episode: 95
# INFO:logger:Episode: 96
# INFO:logger:Episode: 97
# INFO:logger:Episode: 98
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-4d23351e676a> in <module>()
# ----> 1 sim.simulate(100)
#       2 plot_durations(sim.episode_durations)
#
# ~/Desktop/DeepRL-Pytorch/classes/simulator.py in simulate(self, num_episodes)
#     122                 self.simulator.transition()
#     123                 # Perform one step of the optimization for policy net
# --> 124                 self.simulator.learner.optimize_model()
#     125
#     126                 if done:
#
# ~/Desktop/DeepRL-Pytorch/classes/learner.py in optimize_model(self)
#      80         # Compute V(s_{t+1}) for all next states.
#      81         next_state_values = torch.zeros(self.constants["BATCH_SIZE"], device=device)
# ---> 82         next_state_values[non_final_mask] = self.target_net(non_final_next_states).max(1)[0].detach()
#      83         # Compute the expected Q values
#      84         expected_state_action_values = (next_state_values * self.constants["GAMMA"]) + reward_batch
#
# /anaconda3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/Desktop/DeepRL-Pytorch/classes/models.py in forward(self, x)
#      29         x = F.relu(self.bn1(self.conv1(x)))
#      30         x = F.relu(self.bn2(self.conv2(x)))
# ---> 31         x = F.relu(self.bn3(self.conv3(x)))
#      32         x = self.head(x.view(x.size(0), -1))
#      33         #print(x)
#
# /anaconda3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# /anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     299     def forward(self, input):
#     300         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 301                         self.padding, self.dilation, self.groups)
#     302
#     303
#
# KeyboardInterrupt:

# %%
plot_durations(sim.episode_durations)
